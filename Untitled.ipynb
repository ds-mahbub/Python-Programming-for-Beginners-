# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
my_dict = {
    'Hours_Studied':[1,2,3,4,5],
    'Grade':[52,57,66,74,80]
}

# %%
df =pd.DataFrame(my_dict)
df

# %%
print(df)
# Out:
#    Hours_Studied  Grade
# 0              1     52
# 1              2     57
# 2              3     66
# 3              4     74
# 4              5     80

# %%
df.plot(kind='scatter', x='Hours_Studied', y='Grade', title='Hours_Studied vs Grade')
# Out:
# <AxesSubplot:title={'center':'Hours_Studied vs Grade'}, xlabel='Hours_Studied', ylabel='Grade'>

# %%
print(df.corr())
# Out:
#                Hours_Studied     Grade
# Hours_Studied       1.000000  0.996361
# Grade               0.996361  1.000000
